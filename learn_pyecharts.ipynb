# %%
import numpy as np
import pyecharts.options as opts
from pyecharts.charts import Scatter

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x)
y2 = np.cos(x)

# %% [markdown]
# ## 绘制散点图

# %%
(Scatter()
    .add_xaxis(xaxis_data=x)
    .add_yaxis(series_name='sin',y_axis=y)#series_name必须写，如不用可写‘’
    .add_yaxis(series_name='cos',y_axis=y2,label_opts=opts.LabelOpts(is_show=False))
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="37d582498c45463dbe9ebe144037d761" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_37d582498c45463dbe9ebe144037d761 = echarts.init(
#                     document.getElementById('37d582498c45463dbe9ebe144037d761'), 'white', {renderer: 'canvas'});
#                 var option_37d582498c45463dbe9ebe144037d761 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "sin",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     0.0,
#                     0.0
#                 ],
#                 [
#                     0.06346651825433926,
#                     0.0634239196565645
#                 ],
#                 [
#                     0.12693303650867852,
#                     0.12659245357374926
#                 ],
#                 [
#                     0.1903995547630178,
#                     0.18925124436041021
#                 ],
#                 [
#                     0.25386607301735703,
#                     0.2511479871810792
#                 ],
#                 [
#                     0.3173325912716963,
#                     0.3120334456984871
#                 ],
#                 [
#                     0.3807991095260356,
#                     0.3716624556603276
#                 ],
#                 [
#                     0.4442656277803748,
#                     0.42979491208917164
#                 ],
#                 [
#                     0.5077321460347141,
#                     0.4861967361004687
#                 ],
#                 [
#                     0.5711986642890533,
#                     0.5406408174555976
#                 ],
#                 [
#                     0.6346651825433925,
#                     0.5929079290546404
#                 ],
#                 [
#                     0.6981317007977318,
#                     0.6427876096865393
#                 ],
#                 [
#                     0.7615982190520711,
#                     0.690079011482112
#                 ],
#                 [
#                     0.8250647373064104,
#                     0.7345917086575333
#                 ],
#                 [
#                     0.8885312555607496,
#                     0.7761464642917568
#                 ],
#                 [
#                     0.9519977738150889,
#                     0.8145759520503357
#                 ],
#                 [
#                     1.0154642920694281,
#                     0.8497254299495144
#                 ],
#                 [
#                     1.0789308103237674,
#                     0.8814533634475821
#                 ],
#                 [
#                     1.1423973285781066,
#                     0.9096319953545183
#                 ],
#                 [
#                     1.2058638468324459,
#                     0.9341478602651067
#                 ],
#                 [
#                     1.269330365086785,
#                     0.9549022414440739
#                 ],
#                 [
#                     1.3327968833411243,
#                     0.9718115683235417
#                 ],
#                 [
#                     1.3962634015954636,
#                     0.984807753012208
#                 ],
#                 [
#                     1.4597299198498028,
#                     0.9938384644612541
#                 ],
#                 [
#                     1.5231964381041423,
#                     0.998867339183008
#                 ],
#                 [
#                     1.5866629563584815,
#                     0.9998741276738751
#                 ],
#                 [
#                     1.6501294746128208,
#                     0.9968547759519424
#                 ],
#                 [
#                     1.71359599286716,
#                     0.9898214418809327
#                 ],
#                 [
#                     1.7770625111214993,
#                     0.9788024462147787
#                 ],
#                 [
#                     1.8405290293758385,
#                     0.963842158559942
#                 ],
#                 [
#                     1.9039955476301778,
#                     0.9450008187146685
#                 ],
#                 [
#                     1.967462065884517,
#                     0.9223542941045814
#                 ],
#                 [
#                     2.0309285841388562,
#                     0.8959937742913359
#                 ],
#                 [
#                     2.0943951023931957,
#                     0.8660254037844386
#                 ],
#                 [
#                     2.1578616206475347,
#                     0.8325698546347714
#                 ],
#                 [
#                     2.221328138901874,
#                     0.795761840530832
#                 ],
#                 [
#                     2.284794657156213,
#                     0.7557495743542583
#                 ],
#                 [
#                     2.3482611754105527,
#                     0.7126941713788627
#                 ],
#                 [
#                     2.4117276936648917,
#                     0.6667690005162916
#                 ],
#                 [
#                     2.475194211919231,
#                     0.6181589862206052
#                 ],
#                 [
#                     2.53866073017357,
#                     0.5670598638627709
#                 ],
#                 [
#                     2.6021272484279097,
#                     0.5136773915734063
#                 ],
#                 [
#                     2.6655937666822487,
#                     0.4582265217274105
#                 ],
#                 [
#                     2.729060284936588,
#                     0.4009305354066136
#                 ],
#                 [
#                     2.792526803190927,
#                     0.3420201433256689
#                 ],
#                 [
#                     2.8559933214452666,
#                     0.28173255684142967
#                 ],
#                 [
#                     2.9194598396996057,
#                     0.2203105327865408
#                 ],
#                 [
#                     2.982926357953945,
#                     0.1580013959733499
#                 ],
#                 [
#                     3.0463928762082846,
#                     0.09505604330418244
#                 ],
#                 [
#                     3.1098593944626236,
#                     0.031727933498067656
#                 ],
#                 [
#                     3.173325912716963,
#                     -0.03172793349806786
#                 ],
#                 [
#                     3.236792430971302,
#                     -0.09505604330418263
#                 ],
#                 [
#                     3.3002589492256416,
#                     -0.15800139597335008
#                 ],
#                 [
#                     3.3637254674799806,
#                     -0.22031053278654056
#                 ],
#                 [
#                     3.42719198573432,
#                     -0.28173255684142984
#                 ],
#                 [
#                     3.490658503988659,
#                     -0.34202014332566866
#                 ],
#                 [
#                     3.5541250222429985,
#                     -0.4009305354066138

# %% [markdown]
# ## 绘制线图

# %%
from pyecharts.charts import Line
import pyecharts.options as opts

x = np.linspace(0,2*np.pi,100)
y = np.sin(x)
y2 = np.cos(x)

(
    Line()
    .add_xaxis(xaxis_data=x)
    .add_yaxis(series_name='sin',y_axis=y,label_opts=opts.LabelOpts(is_show=False))#label_opts=opts.LabelOpts(is_show=False表示不显示label
    .add_yaxis(series_name='cos',y_axis=y2,label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title='曲线'),#设置标题
                    tooltip_opts=opts.TooltipOpts(axis_pointer_type='cross'))#当鼠标放到对应点下，有参考线，显示横纵坐标
).render()#render生成html文件
# Out:
# 'D:\\Software\\Jupyter notebook\\render.html'

# %% [markdown]
# ## 绘制饼图

# %%
from pyecharts.charts import Pie
import pyecharts.options as opts

num = [110, 136, 108, 48, 111, 112, 103]
lab = ['哈士奇','萨摩耶','泰迪','金毛','牧羊犬','吉娃娃','柯基']

(
    Pie(init_opts=opts.InitOpts(width='720px',height='320px'))#通过InitOpts设置初始画布大小
    .add(series_name='',data_pair=[(j,i) for i,j in zip(num, lab)])#饼图中使用data_pair输入数据
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="17720da8e5ed4c669ec587322f2b3e02" style="width:720px; height:320px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_17720da8e5ed4c669ec587322f2b3e02 = echarts.init(
#                     document.getElementById('17720da8e5ed4c669ec587322f2b3e02'), 'white', {renderer: 'canvas'});
#                 var option_17720da8e5ed4c669ec587322f2b3e02 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 48
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 111
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 112
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 103
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_17720da8e5ed4c669ec587322f2b3e02.setOption(option_17720da8e5ed4c669ec587322f2b3e02);
#         });
#     </script>

# %% [markdown]
# ## 绘制环图

# %%
from pyecharts.charts import Pie
import pyecharts.options as opts

num = [110, 136, 108, 48, 111, 112, 103]
lab = ['哈士奇','萨摩耶','泰迪','金毛','牧羊犬','吉娃娃','柯基']

(
    Pie(init_opts=opts.InitOpts(width='720px',height='320px'))#通过InitOpts设置初始画布大小
    .add(series_name='',data_pair=[(j,i) for i,j in zip(num, lab)],radius=['40%','75%'])#radius第一个参数表示内圆半径，第二个参数表示外圆半径
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="79bcc1587c374fc0b3ad01dcc75e4a76" style="width:720px; height:320px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_79bcc1587c374fc0b3ad01dcc75e4a76 = echarts.init(
#                     document.getElementById('79bcc1587c374fc0b3ad01dcc75e4a76'), 'white', {renderer: 'canvas'});
#                 var option_79bcc1587c374fc0b3ad01dcc75e4a76 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 48
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 111
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 112
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 103
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_79bcc1587c374fc0b3ad01dcc75e4a76.setOption(option_79bcc1587c374fc0b3ad01dcc75e4a76);
#         });
#     </script>

# %% [markdown]
# ## 绘制玫瑰图

# %%
from pyecharts.charts import Pie
import pyecharts.options as opts

num = [110, 136, 108, 48, 111, 112, 103]
lab = ['哈士奇','萨摩耶','泰迪','金毛','牧羊犬','吉娃娃','柯基']

(
    Pie(init_opts=opts.InitOpts(width='720px',height='320px'))#通过InitOpts设置初始画布大小
    .add(series_name='',data_pair=[(j,i) for i,j in zip(num, lab)],rosetype='radius')#rosetype可绘制玫瑰图，每个部分的半径大小根据数量变化
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="691097db31df403d8fa19b6f7d765a40" style="width:720px; height:320px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_691097db31df403d8fa19b6f7d765a40 = echarts.init(
#                     document.getElementById('691097db31df403d8fa19b6f7d765a40'), 'white', {renderer: 'canvas'});
#                 var option_691097db31df403d8fa19b6f7d765a40 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 48
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 111
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 112
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 103
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_691097db31df403d8fa19b6f7d765a40.setOption(option_691097db31df403d8fa19b6f7d765a40);
#         });
#     </script>

# %% [markdown]
# ## 绘制柱状图

# %%
from pyecharts.charts import Bar
import pyecharts.options as opts

num = [110, 136, 108, 48, 111, 112, 103]
num2 = [90, 110, 101, 70, 90, 120, 99]
lab = ['哈士奇','萨摩耶','泰迪','金毛','牧羊犬','吉娃娃','柯基']

(
    Bar(init_opts = opts.InitOpts(width='720px',height='320px'))
    .add_xaxis(lab)
    .add_yaxis('商家A',num)
    .add_yaxis('商家',num2)
    .set_global_opts(title_opts=opts.TitleOpts(title='各个商家拥有犬类数量情况',subtitle='我是副标题'))#设置标题
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4226cf198e294bb0bdbe707b129961bd" style="width:720px; height:320px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4226cf198e294bb0bdbe707b129961bd = echarts.init(
#                     document.getElementById('4226cf198e294bb0bdbe707b129961bd'), 'white', {renderer: 'canvas'});
#                 var option_4226cf198e294bb0bdbe707b129961bd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 110,
#                 136,
#                 108,
#                 48,
#                 111,
#                 112,
#                 103
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6",
#             "legendHoverLink": true,
#             "data": [
#                 90,
#                 110,
#                 101,
#                 70,
#                 90,
#                 120,
#                 99
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u4e2a\u5546\u5bb6\u62e5\u6709\u72ac\u7c7b\u6570\u91cf\u60c5\u51b5",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_4226cf198e294bb0bdbe707b129961bd.setOption(option_4226cf198e294bb0bdbe707b129961bd);
#         });
#     </script>

# %% [markdown]
# ## 多图单图分别绘制

# %%
from pyecharts.charts import Grid, Line, Scatter
import pyecharts.options as opts

x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

lines=(
    Line()
    .add_xaxis(x)
    .add_yaxis('sin(x)', y, label_opts=opts.LabelOpts(is_show=False))
)

points=(
    Scatter()
    .add_xaxis(x)
    .add_yaxis('sin(x)', y, label_opts=opts.LabelOpts(is_show=False))
)

(
    Grid(init_opts=opts.InitOpts(width='720px',height='320px'))                           #如果不添加Grid,那么后绘制的图会覆盖前一个图
   # .add(points,grid_opts=opts.GridOpts(pos_bottom='60%'))  #同一画布上下显示两张图
   # .add(lines,grid_opts=opts.GridOpts(pos_top='60%'))
    .add(points,grid_opts=opts.GridOpts(pos_left='60%'))  #同一画布左右显示两张图
    .add(lines,grid_opts=opts.GridOpts(pos_right='60%'))
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="55928ae02252464e9cc02fd74ff1dc05" style="width:720px; height:320px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_55928ae02252464e9cc02fd74ff1dc05 = echarts.init(
#                     document.getElementById('55928ae02252464e9cc02fd74ff1dc05'), 'white', {renderer: 'canvas'});
#                 var option_55928ae02252464e9cc02fd74ff1dc05 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "sin(x)",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 10,
#             "data": [
#                 [
#                     0.0,
#                     0.0
#                 ],
#                 [
#                     0.06346651825433926,
#                     0.0634239196565645
#                 ],
#                 [
#                     0.12693303650867852,
#                     0.12659245357374926
#                 ],
#                 [
#                     0.1903995547630178,
#                     0.18925124436041021
#                 ],
#                 [
#                     0.25386607301735703,
#                     0.2511479871810792
#                 ],
#                 [
#                     0.3173325912716963,
#                     0.3120334456984871
#                 ],
#                 [
#                     0.3807991095260356,
#                     0.3716624556603276
#                 ],
#                 [
#                     0.4442656277803748,
#                     0.42979491208917164
#                 ],
#                 [
#                     0.5077321460347141,
#                     0.4861967361004687
#                 ],
#                 [
#                     0.5711986642890533,
#                     0.5406408174555976
#                 ],
#                 [
#                     0.6346651825433925,
#                     0.5929079290546404
#                 ],
#                 [
#                     0.6981317007977318,
#                     0.6427876096865393
#                 ],
#                 [
#                     0.7615982190520711,
#                     0.690079011482112
#                 ],
#                 [
#                     0.8250647373064104,
#                     0.7345917086575333
#                 ],
#                 [
#                     0.8885312555607496,
#                     0.7761464642917568
#                 ],
#                 [
#                     0.9519977738150889,
#                     0.8145759520503357
#                 ],
#                 [
#                     1.0154642920694281,
#                     0.8497254299495144
#                 ],
#                 [
#                     1.0789308103237674,
#                     0.8814533634475821
#                 ],
#                 [
#                     1.1423973285781066,
#                     0.9096319953545183
#                 ],
#                 [
#                     1.2058638468324459,
#                     0.9341478602651067
#                 ],
#                 [
#                     1.269330365086785,
#                     0.9549022414440739
#                 ],
#                 [
#                     1.3327968833411243,
#                     0.9718115683235417
#                 ],
#                 [
#                     1.3962634015954636,
#                     0.984807753012208
#                 ],
#                 [
#                     1.4597299198498028,
#                     0.9938384644612541
#                 ],
#                 [
#                     1.5231964381041423,
#                     0.998867339183008
#                 ],
#                 [
#                     1.5866629563584815,
#                     0.9998741276738751
#                 ],
#                 [
#                     1.6501294746128208,
#                     0.9968547759519424
#                 ],
#                 [
#                     1.71359599286716,
#                     0.9898214418809327
#                 ],
#                 [
#                     1.7770625111214993,
#                     0.9788024462147787
#                 ],
#                 [
#                     1.8405290293758385,
#                     0.963842158559942
#                 ],
#                 [
#                     1.9039955476301778,
#                     0.9450008187146685
#                 ],
#                 [
#                     1.967462065884517,
#                     0.9223542941045814
#                 ],
#                 [
#                     2.0309285841388562,
#                     0.8959937742913359
#                 ],
#                 [
#                     2.0943951023931957,
#                     0.8660254037844386
#                 ],
#                 [
#                     2.1578616206475347,
#                     0.8325698546347714
#                 ],
#                 [
#                     2.221328138901874,
#                     0.795761840530832
#                 ],
#                 [
#                     2.284794657156213,
#                     0.7557495743542583
#                 ],
#                 [
#                     2.3482611754105527,
#                     0.7126941713788627
#                 ],
#                 [
#                     2.4117276936648917,
#                     0.6667690005162916
#                 ],
#                 [
#                     2.475194211919231,
#                     0.6181589862206052
#                 ],
#                 [
#                     2.53866073017357,
#                     0.5670598638627709
#                 ],
#                 [
#                     2.6021272484279097,
#                     0.5136773915734063
#                 ],
#                 [
#                     2.6655937666822487,
#                     0.4582265217274105
#                 ],
#                 [
#                     2.729060284936588,
#                     0.4009305354066136
#                 ],
#                 [
#                     2.792526803190927,
#                     0.3420201433256689
#                 ],
#                 [
#                     2.8559933214452666,
#                     0.28173255684142967
#                 ],
#                 [
#                     2.9194598396996057,
#                     0.2203105327865408
#                 ],
#                 [
#                     2.982926357953945,
#                     0.1580013959733499
#                 ],
#                 [
#                     3.0463928762082846,
#                     0.09505604330418244
#                 ],
#                 [
#                     3.1098593944626236,
#                     0.031727933498067656
#                 ],
#                 [
#                     3.173325912716963,
#                     -0.03172793349806786
#                 ],
#                 [
#                     3.236792430971302,
#                     -0.09505604330418263
#                 ],
#                 [
#                     3.3002589492256416,
#                     -0.15800139597335008
#                 ],
#                 [
#                     3.3637254674799806,
#                     -0.22031053278654056
#                 ],
#                 [
#                     3.42719198573432,
#                     -0.28173255684142984
#                 ],
#                 [
#                     3.490658503988659,
#                     -0.34202014332566866
#                 ],
#                 [
#                     3.5541250222429

# %% [markdown]
# ## 多图并行绘制

# %%
from pyecharts.charts import Bar, Line

num = [110, 136, 108, 48, 111, 112, 103]
lab = ['哈士奇','萨摩耶','泰迪','金毛','牧羊犬','吉娃娃','柯基']

bar = (
    Bar(init_opts=opts.InitOpts(width='720px',height='320px'))
    .add_xaxis(lab)
    .add_yaxis('',num)
)

lines = (
    Line()
    .add_xaxis(lab)
    .add_yaxis('',num,label_opts=opts.LabelOpts(is_show=False))
)

bar.overlap(lines).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="744c541f4fb8461286b6c3fc22102513" style="width:720px; height:320px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_744c541f4fb8461286b6c3fc22102513 = echarts.init(
#                     document.getElementById('744c541f4fb8461286b6c3fc22102513'), 'white', {renderer: 'canvas'});
#                 var option_744c541f4fb8461286b6c3fc22102513 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 110,
#                 136,
#                 108,
#                 48,
#                 111,
#                 112,
#                 103
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u54c8\u58eb\u5947",
#                     110
#                 ],
#                 [
#                     "\u8428\u6469\u8036",
#                     136
#                 ],
#                 [
#                     "\u6cf0\u8fea",
#                     108
#                 ],
#                 [
#                     "\u91d1\u6bdb",
#                     48
#                 ],
#                 [
#                     "\u7267\u7f8a\u72ac",
#                     111
#                 ],
#                 [
#                     "\u5409\u5a03\u5a03",
#                     112
#                 ],
#                 [
#                     "\u67ef\u57fa",
#                     103
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_744c541f4fb8461286b6c3fc22102513.setOption(option_744c541f4fb8461286b6c3fc22102513);
#         });
#     </script>

# %% [markdown]
# ## 地理图表绘制

# %%
from pyecharts.charts import Geo
import pyecharts.options as opts
from commons import Faker

(
    Geo()
    .add_schema(maptype='china')#设置地图类型是中国地图
    .add(series_name='',data_pair=[(i, j) for i, j in zip(Faker.provinces,Faker.values())],label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title='中国地图'),
        visualmap_opts=opts.VisualMapOpts(is_piecewise='True')#is_piecewise设置是左下角一段一段的还是连续性的
    )
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="39199a8490714e84b6f386e9c36ec684" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_39199a8490714e84b6f386e9c36ec684 = echarts.init(
#                     document.getElementById('39199a8490714e84b6f386e9c36ec684'), 'white', {renderer: 'canvas'});
#                 var option_39199a8490714e84b6f386e9c36ec684 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         67
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         53
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         28
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         135
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         92
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         43
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         128
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u4e2d\u56fd\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_39199a8490714e84b6f386e9c36ec684.setOption(option_39199a8490714e84b6f386e9c36ec684);
#         });
#     </script>

# %%
from pyecharts.charts import Geo
import pyecharts.options as opts
from pyecharts.globals import ChartType
from commons import Faker

(
    Geo()
    .add_schema(maptype='china')#设置地图类型是中国地图
    .add(series_name='',data_pair=[(i, j) for i, j in zip(Faker.provinces,Faker.values())],type_=ChartType.EFFECT_SCATTER,label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title='中国地图（特效散点图）'),
        visualmap_opts=opts.VisualMapOpts(is_piecewise='True')#is_piecewise设置是左下角一段一段的还是连续性的
    )
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="8b285a4fdeae41b6b86b39dca95993cb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_8b285a4fdeae41b6b86b39dca95993cb = echarts.init(
#                     document.getElementById('8b285a4fdeae41b6b86b39dca95993cb'), 'white', {renderer: 'canvas'});
#                 var option_8b285a4fdeae41b6b86b39dca95993cb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         134
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         88
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         107
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         139
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         116
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         79
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         132
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u4e2d\u56fd\u5730\u56fe\uff08\u7279\u6548\u6563\u70b9\u56fe\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_8b285a4fdeae41b6b86b39dca95993cb.setOption(option_8b285a4fdeae41b6b86b39dca95993cb);
#         });
#     </script>

# %% [markdown]
# ## 地理迁徙图

# %%
from pyecharts.charts import Geo
import pyecharts.options as opts
from pyecharts.globals import ChartType,SymbolType

city_num = [('广州',105),('成都',70),('北京',99),('西安',80)]
stard_end = [('广州','成都'),('广州','北京'),('广州','西安')]

(
    Geo()
    .add_schema(maptype='china',  #地图类型
               itemstyle_opts=opts.ItemStyleOpts(color='#323c48',border_color='#111')) #地图个性化设置
    .add('', data_pair=city_num, color='white') #输入数据
    .add('',data_pair=stard_end, type_=ChartType.LINES, #添加线条
         effect_opts=opts.EffectOpts(symbol=SymbolType.ARROW, 
                                     color='yellow',
                                     symbol_size=8),#动态效果，大小为8的黄色箭头
        label_opts=opts.LabelOpts(is_show=False))
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="bff82b69ce354d399a233c11e6ec007c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_bff82b69ce354d399a233c11e6ec007c = echarts.init(
#                     document.getElementById('bff82b69ce354d399a233c11e6ec007c'), 'white', {renderer: 'canvas'});
#                 var option_bff82b69ce354d399a233c11e6ec007c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "white",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         105
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         70
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         99
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         80
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "lines",
#             "coordinateSystem": "geo",
#             "zlevel": 3,
#             "progressive": 400,
#             "progressiveThreshold": 3000,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4,
#                 "color": "yellow",
#                 "symbol": "arrow",
#                 "symbolSize": 8
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": false,
#             "large": false,
#             "largeThreshold": 2000,
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde->\u6210\u90fd",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             104.06,
#                             30.67
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u897f\u5b89",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             108.95,
#                             34.27
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "itemStyle": {
#             "color": "#323c48",
#             "borderColor": "#111"
#         },
#         "emphasis": {}
#     }
# };
#                 chart_bff82b69ce354d399a233c11e6ec007c.setOption(option_bff82b69ce354d399a233c11e6ec007c);
#         });
#     </script>

# %% [markdown]
# ## 广东热力图

# %%
from pyecharts.charts import Geo  #Geo基于经纬度
import pyecharts.options as opts
from pyecharts.globals import ChartType

(
    Geo()
    .add_schema(maptype='广东')
    .add(series_name='',data_pair=[(i, j) for i, j in zip(Faker.guangdong_city,Faker.values())],
        type_=ChartType.HEATMAP) #热力图
    .set_global_opts(visualmap_opts=opts.VisualMapOpts())#视觉颜色配置项
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="9a69c5a9d13a46fc8d90579f97f7c8b9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_9a69c5a9d13a46fc8d90579f97f7c8b9 = echarts.init(
#                     document.getElementById('9a69c5a9d13a46fc8d90579f97f7c8b9'), 'white', {renderer: 'canvas'});
#                 var option_9a69c5a9d13a46fc8d90579f97f7c8b9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u6c55\u5934\u5e02",
#                     "value": [
#                         116.68,
#                         23.35,
#                         84
#                     ]
#                 },
#                 {
#                     "name": "\u6c55\u5c3e\u5e02",
#                     "value": [
#                         115.37,
#                         22.78,
#                         124
#                     ]
#                 },
#                 {
#                     "name": "\u63ed\u9633\u5e02",
#                     "value": [
#                         116.37,
#                         23.55,
#                         135
#                     ]
#                 },
#                 {
#                     "name": "\u9633\u6c5f\u5e02",
#                     "value": [
#                         111.98,
#                         21.87,
#                         56
#                     ]
#                 },
#                 {
#                     "name": "\u8087\u5e86\u5e02",
#                     "value": [
#                         112.47,
#                         23.05,
#                         75
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": [
#                         113.27,
#                         23.13,
#                         111
#                     ]
#                 },
#                 {
#                     "name": "\u60e0\u5dde\u5e02",
#                     "value": [
#                         114.42,
#                         23.12,
#                         98
#                     ]
#                 }
#             ],
#             "pointSize": 20,
#             "blurSize": 20
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "\u5e7f\u4e1c",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_9a69c5a9d13a46fc8d90579f97f7c8b9.setOption(option_9a69c5a9d13a46fc8d90579f97f7c8b9);
#         });
#     </script>

# %%
from pyecharts.charts import Map #Map基于地区

(
    Map()
    .add('',[(i, j) for i, j in zip(Faker.guangdong_city,Faker.values())],'广东')
    .set_global_opts(visualmap_opts=opts.VisualMapOpts())#视觉颜色配置项
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="2dd9257015384d7085c6b3be196f3d62" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_2dd9257015384d7085c6b3be196f3d62 = echarts.init(
#                     document.getElementById('2dd9257015384d7085c6b3be196f3d62'), 'white', {renderer: 'canvas'});
#                 var option_2dd9257015384d7085c6b3be196f3d62 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u5e7f\u4e1c",
#             "data": [
#                 {
#                     "name": "\u6c55\u5934\u5e02",
#                     "value": 92
#                 },
#                 {
#                     "name": "\u6c55\u5c3e\u5e02",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u63ed\u9633\u5e02",
#                     "value": 120
#                 },
#                 {
#                     "name": "\u9633\u6c5f\u5e02",
#                     "value": 128
#                 },
#                 {
#                     "name": "\u8087\u5e86\u5e02",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u60e0\u5dde\u5e02",
#                     "value": 80
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_2dd9257015384d7085c6b3be196f3d62.setOption(option_2dd9257015384d7085c6b3be196f3d62);
#         });
#     </script>
